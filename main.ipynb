# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
sarsa = pd.read_csv('sarsa.csv')
sarsa.drop(columns=['Unnamed: 0'], inplace=True)

# %%
sarsa
# Out:
#      Train Episodes  Train Success Rates  Train Time  Test Steps  \
# 0                 4                 0.00    0.000999         3.0
# 1                19                 0.08    0.003007         6.0
# 2                20                 0.05    0.002999         6.0
# 3                 8                 0.00    0.001000         5.0
# 4                13                 0.00    0.002080       100.0
# ..              ...                  ...         ...         ...
# 995              19                 0.07    0.002975         6.0
# 996              21                 0.08    0.004006         6.0
# 997              19                 0.07    0.003966         6.0
# 998              18                 0.07    0.002973         6.0
# 999               5                 0.00    0.001002         4.0
#
#      Test Success Rates
# 0                   0.0
# 1                   1.0
# 2                   1.0
# 3                   0.0
# 4                   0.0
# ..                  ...
# ...

# %%
sns.displot(sarsa, x="Train Episodes")

# %%
sns.displot(sarsa, x="Train Episodes", kind='kde')

# %%
sns.displot(sarsa, x="Train Success Rates")

# %%
sns.displot(sarsa, x='Train Time', kind="kde", bw_adjust=1.5)

# %%
sns.displot(sarsa, x='Test Success Rates')

# %%
sns.displot(sarsa, x='Test Steps')
